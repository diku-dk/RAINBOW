# %%
import matplotlib.pyplot as plt
import numpy as np
import polyscope as ps

from mpl_toolkits.mplot3d import Axes3D
#from stl import mesh

from rainbow.procedural.gears import GearSpec
from rainbow.procedural.gears import GearFactory


ps.init()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       5 from mpl_toolkits.mplot3d import Axes3D
#       6 #from stl import mesh
# ----> 8 from rainbow.procedural.gears import GearSpec
#       9 from rainbow.procedural.gears import GearFactory
#      12 ps.init()
#
# File c:\Users\Sofus\source\repos\thesis\RAINBOW\rainbow\procedural\gears\__init__.py:1
# ----> 1 from .generators import *
#       2 from .mating import *
#       3 from .types import *
#
# File c:\Users\Sofus\source\repos\thesis\RAINBOW\rainbow\procedural\gears\generators.py:6
#       4 import rainbow.procedural.gears.mating as MATING
#       5 import rainbow.geometry.surface_mesh as MESH
# ----> 6 import rainbow.simulators.prox_rigid_bodies.api as API
#       8 from .types import Gear, GearSpec, PlanetaryGearSpec, PlanetaryGear
#      11 class GearFactory:
#
# ...

# %%
spec = GEARS.GearSpec(1, 17, bevel_cone_angle=20)
factory = GEARS.GearFactory()
gear = factory.create_gear(spec, 10)

ps_mesh = ps.register_surface_mesh("gear", gear.mesh.V, gear.mesh.T)
print(len(gear.mesh.V))
ps.show()
# Out:
# 2210
